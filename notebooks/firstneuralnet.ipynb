# %%
import numpy as np

#sensitive of the net
weight = 0.1

#defining the neural network with  one input
def neural_net(input,weight):
    prediction = input * weight
    return prediction

# %%
#data
data = [8.5,9.5,10,9]
input = data[0]

pred = neural_net(input,weight)
print(pred)
# Out:
# 0.8500000000000001

# %%
#defining the neural network with multiple inputs
def weight_sum(a,b):
    assert (len(a) == len(b))
    output = 0
    for i in range(len(a)):
        output += (a[i] * b[i])
    return output

def neural_net_multiple_inputs(input,weight):
    pred = weight_sum(input,weight)
    return pred

weights = [0.1,0.2,0]
toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

input = [toes[0],wlrec[0],nfans[0]] #first time
pred = neural_net_multiple_inputs(input,weights)
print(pred)
# Out:
# 0.9800000000000001

# %%
# neural net with hidden layers
def neural_network_with_hidden_layers(input, weights):
    hid = input.dot(weights[0])
    pred = hid.dot(weights[1])
    return pred

ih_wgt = np.array([
[0.1, 0.2, -0.1], # hid[0]
[-0.1,0.1, 0.9], # hid[1]
[0.1, 0.4, 0.1]]).T # hid[2]

hp_wgt = np.array([
[0.3, 1.1, -0.3], # hurt?
[0.1, 0.2, 0.0], # win?
[0.0, 1.3, 0.1] ]).T # sad?

weights = [ih_wgt, hp_wgt]

toes = np.array([8.5, 9.5, 9.9, 9.0])
wlrec = np.array([0.65,0.8, 0.8, 0.9])
nfans = np.array([1.2, 1.3, 0.5, 1.0])
input = np.array([toes[0],wlrec[0],nfans[0]]) #first time
pred = neural_network(input,weights)
print(pred)
# Out:
# [0.2135 0.145  0.5065]

# %%
# applying hot and cold learning for wiggling the weights of the neural net
weight = 0.5
input = 0.5
goal_prediction = 0.8
step_amount = 0.001

for iteration in range(20):
    prediction = input * weight
    error = (prediction - goal_prediction) ** 2
    print("Error:" + str(error) + " Prediction:" + str  (prediction))

up_prediction = input * (weight + step_amount)
up_error = (goal_prediction - up_prediction) ** 2
down_prediction = input * (weight - step_amount)
down_error = (goal_prediction - down_prediction) ** 2

if(down_error < up_error):
    weight = weight - step_amount
if(down_error > up_error):
    weight = weight + step_amount
# Out:
# on:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# ...

# %%
#simple gradient descent
weight = 0.5 
goal_prediction = 0.8
input = 0.5

for interaction in range(20):
    pred =  input * weight 
    error = (pred - goal_prediction) ** 2
    direction_and_amount = (pred - goal_prediction) * input
    weight = weight - direction_and_amount

    print("Error:" +  str(error) + "prediction:" + str(pred))
# Out:
# Error:0.30250000000000005prediction:0.25
# Error:0.17015625000000004prediction:0.3875
# Error:0.095712890625prediction:0.49062500000000003
# Error:0.05383850097656251prediction:0.56796875
# Error:0.03028415679931642prediction:0.6259765625
# Error:0.0170348381996155prediction:0.669482421875
# Error:0.00958209648728372prediction:0.70211181640625
# Error:0.005389929274097089prediction:0.7265838623046875
# Error:0.0030318352166796153prediction:0.7449378967285156
# Error:0.0017054073093822882prediction:0.7587034225463867
# Error:0.0009592916115275371prediction:0.76902756690979
# Error:0.0005396015314842384prediction:0.7767706751823426
# Error:0.000303525861459885prediction:0.7825780063867569
# Error:0.00017073329707118678prediction:0.7869335047900676
# Error:9.603747960254256e-05prediction:0.7902001285925507
# Error:5.402108227642978e-05prediction:0.7926500964444131
# Error:3.038685878049206e-05prediction:0.7944875723333098
# Error:1.7092608064027242e-05prediction:0.7958656792499823
# ...

# %%
# gradient descent without alpha and with delta
weight, goal_pred, input = (0.0, 0.8, 0.5)

for iteration in range(20):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    delta = pred - goal_pred
    weight_delta = delta * input
    weight = weight - weight_delta
    print("Error:" + str(error) + " Prediction:" + str(pred))
# Out:
# Error:0.6400000000000001 Prediction:0.0
# Error:0.3600000000000001 Prediction:0.2
# Error:0.2025 Prediction:0.35000000000000003
# Error:0.11390625000000001 Prediction:0.4625
# Error:0.06407226562500003 Prediction:0.546875
# Error:0.036040649414062535 Prediction:0.61015625
# Error:0.020272865295410177 Prediction:0.6576171875
# Error:0.011403486728668217 Prediction:0.693212890625
# Error:0.006414461284875877 Prediction:0.71990966796875
# Error:0.0036081344727426873 Prediction:0.7399322509765625
# Error:0.0020295756409177616 Prediction:0.7549491882324219
# Error:0.001141636298016239 Prediction:0.7662118911743164
# Error:0.0006421704176341359 Prediction:0.7746589183807373
# Error:0.00036122085991920354 Prediction:0.7809941887855529
# Error:0.000203186733704552 Prediction:0.7857456415891647
# Error:0.0001142925377088099 Prediction:0.7893092311918736
# Error:6.428955246120602e-05 Prediction:0.7919819233939052
# Error:3.616287325942905e-05 Prediction:0.7939864425454288
# ...

# %%
#gradient descent with one input and alpha
weight = 0.5
goal_pred = 0.8
input = 2
alpha = 0.1

for i in range(20):
    pred = input * weight
    error = (pred - goal_pred) ** 2
    derivative = input * ( pred - goal_pred)
    weight = weight - (alpha * derivative)

    print("error:" + str(error) + "prediction:" + str(pred))
# Out:
# error:0.03999999999999998prediction:1.0
# error:0.0144prediction:0.92
# error:0.005183999999999993prediction:0.872
# error:0.0018662400000000014prediction:0.8432000000000001
# error:0.0006718464000000028prediction:0.8259200000000001
# error:0.00024186470400000033prediction:0.815552
# error:8.70712934399997e-05prediction:0.8093312
# error:3.134566563839939e-05prediction:0.80559872
# error:1.1284439629823931e-05prediction:0.803359232
# error:4.062398266736526e-06prediction:0.8020155392
# error:1.4624633760252567e-06prediction:0.8012093235200001
# error:5.264868153690924e-07prediction:0.8007255941120001
# error:1.8953525353291194e-07prediction:0.8004353564672001
# error:6.82326912718715e-08prediction:0.8002612138803201
# error:2.456376885786678e-08prediction:0.8001567283281921
# error:8.842956788836216e-09prediction:0.8000940369969153
# error:3.1834644439835434e-09prediction:0.8000564221981492
# error:1.1460471998340758e-09prediction:0.8000338533188895
# ...
