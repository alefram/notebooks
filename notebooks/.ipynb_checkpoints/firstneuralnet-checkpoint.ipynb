# %%
import numpy as np

#sensitive of the net
weight = 0.1

#defining the neural network with  one input
def neural_net(input,weight):
    prediction = input * weight
    return prediction
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-fc49d47a1bbe> in <module>()
# ----> 1 import numpy as np
#       2
#       3 #sensitive of the net
#       4 weight = 0.1
#       5
#
# ImportError: No module named numpy

# %%
#data
data = [8.5,9.5,10,9]
input = data[0]

pred = neural_net(input,weight)
print(pred)
# Out:
# 0.8500000000000001

# %%
#defining the neural network with multiple inputs
def weight_sum(a,b):
    assert (len(a) == len(b))
    output = 0
    for i in range(len(a)):
        output += (a[i] * b[i])
    return output

def neural_net_multiple_inputs(input,weight):
    pred = weight_sum(input,weight)
    return pred

weights = [0.1,0.2,0]
toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

input = [toes[0],wlrec[0],nfans[0]] #first time
pred = neural_net_multiple_inputs(input,weights)
print(pred)
# Out:
# 0.9800000000000001

# %%
# neural net with hidden layers
def neural_network_with_hidden_layers(input, weights):
    hid = input.dot(weights[0])
    pred = hid.dot(weights[1])
    return pred

ih_wgt = np.array([
[0.1, 0.2, -0.1], # hid[0]
[-0.1,0.1, 0.9], # hid[1]
[0.1, 0.4, 0.1]]).T # hid[2]

hp_wgt = np.array([
[0.3, 1.1, -0.3], # hurt?
[0.1, 0.2, 0.0], # win?
[0.0, 1.3, 0.1] ]).T # sad?

weights = [ih_wgt, hp_wgt]

toes = np.array([8.5, 9.5, 9.9, 9.0])
wlrec = np.array([0.65,0.8, 0.8, 0.9])
nfans = np.array([1.2, 1.3, 0.5, 1.0])
input = np.array([toes[0],wlrec[0],nfans[0]]) #first time
pred = neural_network(input,weights)
print(pred)
# Out:
# [0.2135 0.145  0.5065]

# %%
# applying hot and cold learning for wiggling the weights of the neural net
weight = 0.5
input = 0.5
goal_prediction = 0.8
step_amount = 0.001

for iteration in range(20):
    prediction = input * weight
    error = (prediction - goal_prediction) ** 2
    print("Error:" + str(error) + " Prediction:" + str  (prediction))

up_prediction = input * (weight + step_amount)
up_error = (goal_prediction - up_prediction) ** 2
down_prediction = input * (weight - step_amount)
down_error = (goal_prediction - down_prediction) ** 2

if(down_error < up_error):
    weight = weight - step_amount
if(down_error > up_error):
    weight = weight + step_amount
# Out:
# on:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25
# Error:0.30250000000000005 Prediction:0.25

# %%
#simple gradient descent
weight = 0.5 
goal_prediction = 0.8
input = 0.5

for interaction in range(20):
    pred =  input * weight 
    error = (pred - goal_prediction) ** 2
    direction_and_amount = (pred - goal_prediction) * input
    weight = weight - direction_and_amount

    print("Error:" +  str(error) + "prediction:" + str(pred))
# Out:
# Error:0.30250000000000005prediction:0.25
# Error:0.17015625000000004prediction:0.3875
# Error:0.095712890625prediction:0.49062500000000003
# Error:0.05383850097656251prediction:0.56796875
# Error:0.03028415679931642prediction:0.6259765625
# Error:0.0170348381996155prediction:0.669482421875
# Error:0.00958209648728372prediction:0.70211181640625
# Error:0.005389929274097089prediction:0.7265838623046875
# Error:0.0030318352166796153prediction:0.7449378967285156
# Error:0.0017054073093822882prediction:0.7587034225463867
# Error:0.0009592916115275371prediction:0.76902756690979
# Error:0.0005396015314842384prediction:0.7767706751823426
# Error:0.000303525861459885prediction:0.7825780063867569
# Error:0.00017073329707118678prediction:0.7869335047900676
# Error:9.603747960254256e-05prediction:0.7902001285925507
# Error:5.402108227642978e-05prediction:0.7926500964444131
# Error:3.038685878049206e-05prediction:0.7944875723333098
# Error:1.7092608064027242e-05prediction:0.7958656792499823
# Error:9.614592036015323e-06prediction:0.7968992594374867
# Error:5.408208020258491e-06prediction:0.7976744445781151

# %% [markdown]
# # activation function

# %%
import numpy as np
input = 10 #whatever input

# standart form to represent act functions

# relu function make derivates

#forward prop
ones_and_zeros = input > 0
output = input*ones_and_zeros

#backprop delta
mask = output > 0
deriv = output * mask
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-bdd5e1841746> in <module>()
# ----> 1 import numpy as np
#       2 input = 10 #whatever input
#       3
#       4 # standart form to represent act functions
#       5
#
# ImportError: No module named numpy

# %%
#sigmoid

#foward prop
output = 1/(1 + np.exp(-input))

#backprop delta
deriv = output*(1-output)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-b6b3648e492d> in <module>()
#       2
#       3 #foward prop
# ----> 4 output = 1/(1 + np.exp(-input))
#       5
#       6 #backprop delta
#
# NameError: name 'np' is not defined

# %%
#tanh

#forward prop
output = np.tanh(input)

#backprop delta
deriv = 1 - (output**2)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-93cbdb4bb84e> in <module>()
#       2
#       3 #forward prop
# ----> 4 output = np.tanh(input)
#       5
#       6 #backprop delta
#
# NameError: name 'np' is not defined

# %%
#softmax

#forward prop
temp = np.exp(input)
output /= np.sum(temp)

#backprop delta
temp = (output - true)
output = temp/len(true)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-e1442bfc20a7> in <module>()
#       2
#       3 #forward prop
# ----> 4 temp = np.exp(input)
#       5 output /= np.sum(temp)
#       6
#
# NameError: name 'np' is not defined

# %%
from torchvision import model
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-35b2f7f88687> in <module>
# ----> 1 from torchvision import model
#
# ImportError: cannot import name 'model' from 'torchvision' (/home/linuxbrew/.linuxbrew/opt/python@3.8/lib/python3.8/site-packages/torchvision/__init__.py)
